# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#                                         Conversation  \
# 0  Grad C: Yeah , we had a long discussion about ...
# 1  ad a long discussion about how much w how easy...
# 2               uch w how easy we want to make it fo
# 3                                how easy we want to
# 4  ker}\nGrad C: Channel three ? Channel three ?\...
#
#                                                Query  \
# 0                        Summarize the whole meeting
# 1  Summarize the discussion about the current XML...
# 2  What did F think about the current XML format ...
# 3  What did A think about the current XML format ...
# 4  Summarize the discussion about the disadvantag...
#
#                                               Answer
# 0  Meeting participants wanted to agree upon a st...
# 1  C developed an XML format that links together ...
# 2  F was concerned about how the time labels woul...
# 3  A had seen an example of this kind of XML form...
# 4  Since the team is familiar with Perl and a fla...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Answer',axis=1)
y = df['Answer']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)
